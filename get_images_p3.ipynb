# %%
import pandas as pd
import numpy as np
import requests
from subprocess import call
import os.path
import os
from PIL import Image
from io import BytesIO

# %%
# In[2]:


# imagenet_urls_df = pd.read_table('fall11_urls.txt', sep="\t", header=None)
# imagenet_urls_df.columns = ['ID','URL']


# # In[12]:


# a = imagenet_urls_df.sample(20000)


# # In[13]:


# a


# # In[14]:


# a.to_csv(r'imagenet_URLs.txt', header=None, index=None, sep=' ', mode='a')


# In[17]:

count=0
if not os.path.exists('./data'):
    os.makedirs('./data')

with open("imagenet_URLs.txt","r") as fp:
    for line in fp:
        line = line.split(" ")
        url = line[1]
        Id = line[0]
        
        try:
            request = requests.get(url)
        except:
            print ("Broken Link!")
            continue

        print (url, Id)
        if request.status_code == 200:
            try:
                img = Image.open(BytesIO(request.content)).convert("RGB")
            except Exception as e:
                print(e)
                print ("Valid Link, but not valid JPG!")
                continue
            
            count+=1
            print (count)
            print('Web site exists... Downloading Image')
            call('wget -O data/'+ Id + ".jpg " + url,shell=True)
            if count == 10000:
                print("10000 Images Collected!")
                break



# img_cover_path = "n12754003_5112.jpg"
# a =  Image.open(img_cover_path).convert("RGB")

# except:
				# print "Valid JPG, but not Valid Image"
# Out:
# http://farm1.static.flickr.com/28/46542949_3ab939ffde.jpg
#  n04067658_10084
# 1
# Web site exists... Downloading Image
# http://www.sciencephoto.com/images/showFullWatermarked.html/M874546-Cultured_pneumonia_bacteria-SPL.jpg?id=778740546
#  n01368672_2391
# 2
# Web site exists... Downloading Image
# http://farm1.static.flickr.com/6/86569928_dddbd07f84.jpg
#  n02009750_8219
# 3
# Web site exists... Downloading Image
# http://farm4.static.flickr.com/3017/2772688624_0b00047c6b.jpg
#  n04146504_1743
# 4
# Web site exists... Downloading Image
# http://farm4.static.flickr.com/3577/3651011884_2b43a8cb2d.jpg
#  n07644244_112
# 5
# Web site exists... Downloading Image
# http://farm3.static.flickr.com/2308/2153000923_ee06f7fe15.jpg
#  n03789171_10541
# 6
# Web site exists... Downloading Image
# http://www.camping-annahoeve.nl/assets/images/b024.jpg
#  n09475925_442
# http://static.flickr.com/1432/892102652_d8e59be3da.jpg
#  n12722071_3707
# 7
# Web site exists... Downloading Image
# http://farm4.static.flickr.com/3588/3341504194_f478c39778.jpg
#  n10034201_27872
# 8
# Web site exists... Downloading Image
# http://farm4.static.flickr.com/3035/2936748884_8ba6b03875.jpg
#  n02005790_10332
# 9
# Web site exists... Downloading Image
# http://www.bbcattle.com/B04011.JPG
#  n02407625_11185
# http://farm4.static.flickr.com/3281/2717856779_d2c53df0c7.jpg
#  n01515303_11918
# 10
# Web site exists... Downloading Image
# Broken Link!
# http://www.greatwindsorchairs.com/images/country_secretary_desk-pu3s.jpg
#  n04164868_23642
# Broken Link!
# http://pro-secondhand.com/images/jizhuangxianghuochuan.jpg
#  n02878222_27698
# http://www.nibbledish.com/public/images/cached/567x/recipe_images/1e1af32a1b309469156815dd7fc9479bwenwenzz_p1050300.jpg
#  n07614198_18115
# 11
# Web site exists... Downloading Image
# http://www.army-technology.com/projects/spada/images/5s_air_defence.jpg
#  n02800940_331
# cannot identify image file <_io.BytesIO object at 0x1052d28e0>
# Valid Link, but not valid JPG!
# http://farm4.static.flickr.com/3097/2739451154_128386e377.jpg
#  n09874862_543
# 12
# Web site exists... Downloading Image
# http://www.painetworks.com/photos/hm/hm2394.JPG
#  n02380745_8208
# 13
# Web site exists... Downloading Image
# http://3.bp.blogspot.com/_XRjPipamta0/Sf0A-6osHZI/AAAAAAAAAq4/cC_pEnuvkHo/s320/DSCN0360.JPG
#  n12843557_3015
# http://www.metaefficient.com/metaefficient/archives/images/P36.jpg
#  n03425241_4678
# http://farm2.static.flickr.com/1250/1382501605_397b27bc1f.jpg
#  n04201297_3465
# 14
# Web site exists... Downloading Image
# Broken Link!
# http://farm1.static.flickr.com/72/170850951_46f509d3b8.jpg
#  n04971313_13780
# 15
# Web site exists... Downloading Image
# http://farm3.static.flickr.com/2618/3680165279_46f7ae8a75.jpg
#  n01638329_1939
# 16
# Web site exists... Downloading Image
# http://www.floracam.co.uk/wildflowers/month/saxifraga_hypnoides2.jpg
#  n12793695_844
# cannot identify image file <_io.BytesIO object at 0x106b431a8>
# Valid Link, but not valid JPG!
# http://farm1.static.flickr.com/65/190394682_4d04bc4c51.jpg
#  n04322531_852
# 17
# Web site exists... Downloading Image
# http://www.devrolijkeviervoeters.org/images/vlo01.gif
#  n02187150_5110
# http://pic1.nipic.com/2008-12-15/2008121585731428_2.jpg
#  n02395694_26853
# http://static-p3.fotolia.com/jpg/00/05/33/44/400_F_5334499_btHvEykUxLSWk1NSIj1TcuQNcFm0NRso.jpg
#  n00006484_5800
# http://farm1.static.flickr.com/126/321574680_4b016de606.jpg
#  n03743902_17677
# 18
# Web site exists... Downloading Image
# http://farm2.static.flickr.com/1004/940799129_a9722d959b.jpg
#  n12683407_9511
# 19
# Web site exists... Downloading Image
# http://www.mikedidonato.com/wp-content/Gorilla.JPG
#  n04119751_5225
# http://gtpine.com.au/content/page_gallery/full/Diagonal%20Lattice_115.jpg
#  n03646148_13522
# http://farm1.static.flickr.com/39/76787526_7e4927bc31.jpg
#  n09305898_20348
# 20
# Web site exists... Downloading Image
# http://www.haigengineering.co.uk/forklift%20red.jpg
#  n03384352_1205
# http://1.bp.blogspot.com/_5lduQCAURdY/Rx4j4FaMMDI/AAAAAAAAAyg/25q-PwwdQl0/s320/Presentation4.jpg
#  n03633091_7053
# 21
# Web site exists... Downloading Image
# http://www.jahrhundertweine.de/u/34aPic1S350362528_zz_MontrachetFL.jpg
#  n07894703_2830
# http://www.no-pest.com/HarvestMouse.JPG
#  n02336275_3343
# cannot identify image file <_io.BytesIO object at 0x104f938e0>
# Valid Link, but not valid JPG!
# http://farm4.static.flickr.com/3240/2852835740_0cefebbc0f.jpg
#  n09263912_23642
# 22
# Web site exists... Downloading Image
# http://farm4.static.flickr.com/3372/3562540584_2e920f98c2.jpg
#  n01791463_7363
# 23
# Web site exists... Downloading Image
# http://cache3.asset-cache.net/xc/84570193.jpg?v=1&c=IWSAsset&k=2&d=77BFBA49EF8789215ABF3343C02EA548A93BE5AEA036A3CC147A5CB5150B7C4FE0D2729336394A5BE30A760B0D811297
#  n09690864_3149
# http://farm4.static.flickr.com/3620/3657214787_d09066151b.jpg
#  n10205231_735
# 24
# Web site exists... Downloading Image
# http://farm1.static.flickr.com/34/72055913_bc4b812fd9.jpg
#  n02025043_899
# 25
# Web site exists... Downloading Image
# http://www.papabearsnorthwoods.com/images/GELH/loft-peak.JPG
#  n04089152_12002
# http://www.fotodigiscoping.info/galeria/data/thumbnails/75/CURRUCA_CABECINEGRA02-1.jpg
#  n01564773_5391
# http://farm3.static.flickr.com/2187/1536254945_388832b3c5.jpg
#  n03861271_4876
# 26
# Web site exists... Downloading Image
# http://farm1.static.flickr.com/34/63870545_32c9f3b25c.jpg
#  n03624400_2155
# 27
# Web site exists... Downloading Image
# http://www.stingersplace.com/images/GFG001712.jpg
#  n12232114_115
# http://farm1.static.flickr.com/21/35161651_60a7c3054f.jpg
#  n03935116_7771
# 28
# Web site exists... Downloading Image
# http://farm3.static.flickr.com/2792/4232439969_df65edb7ac.jpg
#  n09924195_8962
# 29
# Web site exists... Downloading Image
# http://farm4.static.flickr.com/3255/2832692779_b972449e5d.jpg
#  n03443543_1920
# 30
# Web site exists... Downloading Image
# http://farm1.static.flickr.com/33/103914358_19fa6985f0.jpg
#  n02095412_1449
# 31
# Web site exists... Downloading Image
# http://static.flickr.com/3075/2711691805_c99e5df8d0.jpg
#  n11655974_4902
# 32
# Web site exists... Downloading Image
# http://www.pbs.org/wgbh/nova/bomber/images/kamc_hunting.jpg
#  n00452293_38
# 33
# Web site exists... Downloading Image
# http://www.digitaldesktopwallpaper.com/wallpapers/mountain_wallpaper_001_1024.jpg
#  n09359803_3904
# cannot identify image file <_io.BytesIO object at 0x1052d25c8>
# Valid Link, but not valid JPG!
# http://farm4.static.flickr.com/3251/3005773590_635d30dd9b.jpg
#  n09659039_3236
# 34
# Web site exists... Downloading Image
# http://farm3.static.flickr.com/2407/1934899638_82270b73a4.jpg
#  n10624074_3127
# 35
# Web site exists... Downloading Image
# http://www.doctorinformatica.it/bbrondinella/immagini/pattinaggio.jpg
#  n00448466_1887
# http://farm4.static.flickr.com/3641/3621720412_a0bf255dd2.jpg
#  n05218119_14129
# 36
# Web site exists... Downloading Image
# Broken Link!
# http://www.ashmi.org/uploaded/faculty/khallberg/hallberg.jpg
#  n03333610_2900
# http://www.phila.gov/Recreation/images/Kendrick_Golf.jpg
#  n00466273_4056
# http://static.flickr.com/1355/950907811_f9ebb6dfda.jpg
#  n03216402_3170
# 37
# Web site exists... Downloading Image
# Broken Link!
# http://imagecache2.allposters.com/images/pic/NGSPOD/128677_b~Cotton-Grass-Grows-on-Bolshoy-Shantar-Island-Posters.jpg
#  n12152532_6948
# http://www.uwrf.edu/~amanda.prochazka/solimar5.jpg
#  n13223843_581
# http://readandeat.files.wordpress.com/2009/09/fried-ice-cream.jpg
#  n07616748_1453
# http://i.pbase.com/t3/08/586108/4/102102013.HQOg0d3S.jpg
#  n02028900_8406
# http://d.yimg.com/a/p/ap/20090405/capt.ddee36860b3a482db4171e609aba13a4.key_biscayne_tennis_flwl103.jpg
#  n00483313_5116
# http://a248.e.akamai.net/f/248/1229/1d/images.world66.com/tr/in/it/trinity_manse_bb_web
#  n03718935_7345
# http://farm3.static.flickr.com/2199/2054061046_7995f79969.jpg
#  n02088839_26
# 38
# Web site exists... Downloading Image
# http://farm4.static.flickr.com/3527/3714673306_d96108ce57.jpg
#  n03963645_10630
# 39
# Web site exists... Downloading Image
# http://www.carmotorsports.com/prodimages/TurboTValveCapstn.jpg
#  n02957135_3782
# http://farm3.static.flickr.com/2237/2017787317_375abc5648.jpg
#  n09889065_12995
# 40
# Web site exists... Downloading Image
# http://farm4.static.flickr.com/3224/2771392035_9a9291d486.jpg
#  n03941684_18030
# 41
# Web site exists... Downloading Image
# http://www.creationcsp.org/uploaded_images/i-beans-pinto-725835.jpg
#  n13136316_6374
# Broken Link!
# http://farm3.static.flickr.com/2466/3968042050_73ed099e18.jpg
#  n09432283_11567
# 42
# Web site exists... Downloading Image
# http://farm1.static.flickr.com/241/515531102_06192dcd71.jpg
#  n12683407_15616
# 43
# Web site exists... Downloading Image
# http://www.rockinghorsedepot.com/shop/prodimages/web_gift_wrap_large.jpg
#  n04605726_29076
# cannot identify image file <_io.BytesIO object at 0x106b43db0>
# Valid Link, but not valid JPG!
# http://www.swa.be/garage16.jpg
#  n03416640_370
# http://farm4.static.flickr.com/3278/2854158072_27d1551c0d.jpg
#  n10117851_9759
# 44
# Web site exists... Downloading Image
# http://farm3.static.flickr.com/2658/3829916041_411cae53f3.jpg
#  n10732967_19314
# 45
# Web site exists... Downloading Image
# http://farm1.static.flickr.com/170/415440819_5c3b63b39a.jpg
#  n01862399_469
# 46
# Web site exists... Downloading Image
# http://www.pedrospride.com/prodimages/Cashmere%20Boucle2.jpg
#  n02878425_9541
# http://www.nps.gov/pinn/naturescience/images/Westernchainfern.jpg
#  n13185269_5872
# 47
# Web site exists... Downloading Image
# http://erinhession.com/wp-content/uploads/2009/01/0083.jpg
#  n03024233_4117
# http://www.brockvilley.com/images/parentandtotswimatourYPool.jpg
#  n04542858_8160
# http://static.flickr.com/3078/3084249749_e1df3d8081.jpg
#  n00449054_4197
# 48
# Web site exists... Downloading Image
# http://farm3.static.flickr.com/2699/4273799892_f2148a61e4.jpg
#  n12076577_21996
# 49
# Web site exists... Downloading Image
# http://farm4.static.flickr.com/3635/3291117743_4373283d6f.jpg
#  n01965529_7537
# 50
# Web site exists... Downloading Image
# http://farm1.static.flickr.com/36/116841759_2b8f219d52.jpg
#  n11896722_9189
# 51
# Web site exists... Downloading Image
# http://week.divebums.com/2007/Jul23-2007/mola_scott-gietler.jpg
#  n02656670_10470
# http://www.shoalhaven.net.au/shgfc/pics/misc/general/yellowfin_michaelrichards_09jan2003.jpg
#  n02627532_6855
# http://www.mercadolibre.com.ve/jm/img?s=MLV&f=10526427_9462.jpg&v=P
#  n02979186_2029
# 52
# Web site exists... Downloading Image
# http://www.twinsupply.com/vollrathfoodservice/images/large/4838.jpg
#  n04176068_1649
# cannot identify image file <_io.BytesIO object at 0x1052d25c8>
# Valid Link, but not valid JPG!
# http://www.necv.nl/pics/algemeen/torenkraan.jpg
#  n03126707_6433
# http://farm1.static.flickr.com/132/318616401_60873bc563.jpg
#  n02414578_399
# 53
# Web site exists... Downloading Image
# http://farm3.static.flickr.com/2245/1624383499_110ddc91a7.jpg
#  n02090827_281
# 54
# Web site exists... Downloading Image
# http://bp0.blogger.com/_j3iLsob8JEg/SJZB3Ng4d3I/AAAAAAAAA8U/LJF7Af-Ifl8/s320/cena+en+ana+blog+16.JPG
#  n04227900_4476
# 55
# Web site exists... Downloading Image
# http://static.flickr.com/116/258204352_d6afc7de80.jpg
#  n02584449_10505
# 56
# Web site exists... Downloading Image
# http://www.meerzicht.net/images/nieuws/2006/opening2.jpg
#  n10525436_27406
# http://static.flickr.com/44/138296213_b5844469e6.jpg
#  n12269652_937
# 57
# Web site exists... Downloading Image
# http://farm2.static.flickr.com/1314/844668593_d48244c4a8.jpg
#  n12291959_4279
# 58
# Web site exists... Downloading Image
# http://s3.amazonaws.com/m.thumbs.canstockphoto.com/canstock0366617.jpg
#  n08579352_2757
# http://www.co.missoula.mt.us/extension/PlantData/PESTS/rootmaggots/G28-26med.jpg
#  n02312175_2425
# http://farm1.static.flickr.com/50/133514072_8edaca29f5.jpg
#  n03252637_7210
# 59
# Web site exists... Downloading Image
# http://farm4.static.flickr.com/3294/2685408294_2a45333f50.jpg
#  n11950686_5331
# 60
# Web site exists... Downloading Image
# http://farm4.static.flickr.com/3125/2299352161_55e7ca376b.jpg
#  n03297735_2179
# 61
# Web site exists... Downloading Image
# http://farm2.static.flickr.com/1390/1230514585_4622c4b131.jpg
#  n04144241_2661
# 62
# Web site exists... Downloading Image
# http://naturaitaliana.forumgogo.com/data/47/19/4719/a/forumid_3758/20080505_c70dab7e810965e975eeypKAy3tn9HHM.jpg
#  n11949015_2626
# http://fabmania.files.wordpress.com/2008/09/celine-watch-me-work-bag.jpg
#  n04600312_6609
# http://www.javno.com/slike/slike_3/r1/g2009/m03/y198534471877812.jpg
#  n00464651_4049
# http://farm3.static.flickr.com/2137/3540088710_dca68a2b83.jpg
#  n03415252_6242
# 63
# Web site exists... Downloading Image
# http://boston.redsox.mlb.com/images/2008/10/07/lMoVKAHA.jpg
#  n03349771_3299
# http://pics.davesgarden.com/pics/ecrane3_1148349626_295_tn.jpg
#  n11892817_1234
# cannot identify image file <_io.BytesIO object at 0x106b43d58>
# Valid Link, but not valid JPG!
# http://farm4.static.flickr.com/3030/2678992662_a905b4d112.jpg
#  n07690892_1522
# 64
# Web site exists... Downloading Image
# http://farm4.static.flickr.com/3139/2672631097_ddee20975c.jpg
#  n10333601_1640
# 65
# Web site exists... Downloading Image
# http://www.ontariowildflower.com/images/juniper.jpg
#  n12948053_559
# http://www.casarex.net/fgchocgrzdo.jpg
#  n07909129_1894
# http://www.pixartweb.com/gallery/pix/g922.jpg
#  n12754003_5112
# cannot identify image file <_io.BytesIO object at 0x106b43db0>
# Valid Link, but not valid JPG!
# http://farm3.static.flickr.com/2122/2281863595_6af85d970f.jpg
#  n02016358_10338
# 66
# Web site exists... Downloading Image
# http://farm1.static.flickr.com/219/524033401_13b4c831e9.jpg
#  n02726681_8592
# 67
# Web site exists... Downloading Image
# http://farm1.static.flickr.com/121/299888945_9f635b7d50.jpg
#  n01646292_1124
# 68
# Web site exists... Downloading Image
# Broken Link!
